# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with ' mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json '

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import json

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'autosaurus', 'classDB', 'config', 'epa', 'local', 'met', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66d6400859618f317ba9398e'),
#  'geocode': {'latitude': 51.083812, 'longitude': 1.195625},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
# Define the new restaurant data
new_restaurant = {
    "BusinessName": "Penang Flavours",
    "BusinessType": "Restaurant/Cafe/Canteen",
    "BusinessTypeID": "",  # Will update this later
    "AddressLine1": "Penang Flavours",
    "AddressLine2": "146A Plumstead Rd",
    "AddressLine3": "London",
    "AddressLine4": "",
    "PostCode": "SE18 7DY",
    "Phone": "",
    "LocalAuthorityCode": "511",
    "LocalAuthorityName": "Greenwich",
    "LocalAuthorityWebSite": "http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress": "health@royalgreenwich.gov.uk",
    "scores": {
        "Hygiene": "",
        "Structural": "",
        "ConfidenceInManagement": ""
    },
    "SchemeType": "FHRS",
    "geocode": {
        "longitude": "0.08384000",
        "latitude": "51.49014200"
    },
    "RightToReply": "",
    "Distance": 4623.9723280747176,
    "NewRatingPending": True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_restaurant)
# Out:
# InsertOneResult(ObjectId('66d642588e6588895af27fa9'), acknowledged=True)

# %%
# Check that the new restaurant was inserted
query = {"BusinessName": "Penang Flavours"}

results = establishments.find(query)

for results in results:
    pprint(results)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66d642588e6588895af27fa9'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {"BusinessType":"Restaurant/Cafe/Canteen"}

# Set fields to reutn back
fields = {"BusinessTypeID":1, "BusinessTYpe":1}

# Return as a list
results = list(establishments.find(query, fields))
pprint(results)
# Out:
# [{'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936a7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936a8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936ac')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936ad')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936ae')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936af')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936b2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936b5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936b6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936b9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936ba')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936bb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936c6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936c7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936cd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936d7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936d9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936da')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936de')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936df')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936e1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936e4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936e5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936e7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936e8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936e9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936ec')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936ef')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936f1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936f5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936f9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936fb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936fc')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba936ff')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93700')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93701')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9370a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9370b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93713')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93714')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93716')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93719')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9371a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9371b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93721')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93729')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9372a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9372c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93730')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93732')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93733')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93735')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9373a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9373d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93742')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93744')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93746')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9374b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93750')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93754')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93755')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93756')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9375d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93763')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93764')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93768')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9376c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93770')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93772')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93773')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93777')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9377d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9377e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93784')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93791')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93796')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93797')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9379b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937a3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937a5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937a7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937a8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937b1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937b8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937ba')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937bc')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937c3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937c7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937c8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937d1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937d4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937da')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937e0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937e1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937e2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937e5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937e8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937ed')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937ee')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937ef')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937f2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937f3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937f4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937f5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937f7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937f8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937f9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937fb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba937fd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93804')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93806')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9380f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93811')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93814')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93815')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93818')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9381e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93821')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93822')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93825')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93829')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9382b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9382e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93830')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93833')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93834')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9383f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93841')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93845')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93846')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9384a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9384f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93850')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93853')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93854')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9385d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93862')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93869')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9386c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9386f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93871')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93872')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93876')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9387b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93882')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9388b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93897')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba938a1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba938c0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba938cc')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba938ce')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba938d0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba938d2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba938d4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba938e1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba938f5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9390d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93914')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9391d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93920')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93925')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93926')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93933')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9393d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9393e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93945')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9394a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9394d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93950')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93954')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93955')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93959')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9395b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9395e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93961')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9396c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9396e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93970')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93981')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93982')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93986')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93987')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9398e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9399a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba9399c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba939a0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba939a2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba939af')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba939b8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba939bc')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba939be')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba939bf')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba939c4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba939c7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba939d3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba939da')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba939dc')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba939e0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba939e5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba939e7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba939e8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba939ed')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba939ee')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba939ef')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba939f0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba939f2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba939f4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba939f8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba939fb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba939fc')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a02')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a05')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a07')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a08')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a0d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a10')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a16')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a19')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a1b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a1e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a20')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a21')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a22')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a26')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a29')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a2a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a2d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a31')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a32')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a33')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a39')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a3b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a3c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a40')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a42')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a47')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a49')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a4b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a53')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a54')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a56')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a5f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a60')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a61')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a66')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a68')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a6b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a6d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a73')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a75')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a76')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a77')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a7a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a7b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a7c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a81')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a84')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a86')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a91')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a92')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a95')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a96')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a97')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a9a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93a9f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93aa0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93aa2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93aa5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93aa7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93aa8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93aa9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93aad')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93ab0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93ab3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93ab9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93ac5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93ac8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93adb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93ae0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93ae1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93ae8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93aeb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93aee')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93af4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b04')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b0e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b10')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b11')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b13')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b16')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b20')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b22')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b23')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b24')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b25')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b26')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b27')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b2a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b2c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b2d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b2e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b30')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b34')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b3f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b41')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b46')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b47')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b48')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b49')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b4b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b4c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b4d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b4f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b51')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b53')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b54')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b59')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b5b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b62')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b63')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b65')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b66')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b67')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b68')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b6c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b6e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b79')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b7a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b7c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b7f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b80')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b81')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b8a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b8f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b94')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b95')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b98')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b9c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b9d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93b9f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93ba3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93bab')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93bb0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93bb4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93bbc')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93bbe')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93bc0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93bc4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93bc7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93bca')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93bd2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93bd6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93bd9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93bda')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93bdb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba93bdd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400859618f317ba
')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cee0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cee3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cee8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cef0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cef3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cef7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf00')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf01')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf02')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf08')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf0f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf14')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf16')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf17')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf19')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf1a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf1c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf1d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf27')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf2b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf2e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf34')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf37')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf41')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf44')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf47')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf48')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf4a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf4c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf4e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf4f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf50')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf52')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf54')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf56')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf60')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf63')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf69')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf6a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf6d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf70')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf73')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf75')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf76')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf78')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf79')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf7b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf7c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf7d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf84')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf86')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf87')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf89')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf8b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf8f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf94')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf97')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf9a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf9b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf9c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cf9e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cfa6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cfa7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cfaa')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cfab')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cfb5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cfbb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cfbf')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cfc0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cfc8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cfca')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cfcb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cfcd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cfd6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cfd7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cfd8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cfdd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cfdf')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cfe3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cfe4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cfe9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cfea')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cfeb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cfed')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cfee')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cff4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cff5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cff7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cff8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cff9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cffb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9cffe')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d001')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d004')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d006')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d007')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d00f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d016')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d017')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d018')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d01d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d01f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d020')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d021')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d022')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d023')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d025')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d026')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d02b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d02c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d02e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d02f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d031')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d033')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d034')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d037')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d03a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d03e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d042')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d043')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d044')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d045')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d046')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d047')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d04d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d04e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d058')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d059')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d05d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d05f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d066')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d06c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d06f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d071')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d072')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d07a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d09d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d0a3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d0aa')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d0ae')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d0af')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d0b0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d0b4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d0b6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d0b7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d0b8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d0b9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d0ba')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d0bb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d0cd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d0d0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d0db')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d0dc')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d0e5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d0e7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d0ee')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d0f0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d0f5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d0f9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d0fc')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d0fd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d100')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d102')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d10a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d118')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d11c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d128')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d129')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d133')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d134')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d138')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d13b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d141')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d144')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d147')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d14b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d14d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d155')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d158')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d15c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d15d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d15f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d161')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d162')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d163')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d165')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d166')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d168')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d169')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d16b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d170')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d171')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d172')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d174')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d175')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d177')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d178')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d179')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d17b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d17d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d180')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d182')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d188')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d18a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d18b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d18c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d192')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d195')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d198')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d19f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d1a7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d1ae')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d1b1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d1b5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d1b6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d1b7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d1cb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d1cf')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d1d1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d1de')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d1e4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d1e9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d1ec')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d1ef')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d1f4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d1f7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d1f9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('66d6400c59618f317ba9d209')},
#  {'BusinessTypeID': '', '_id': ObjectId('66d642588e6588895af27fa9')}]

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
query = {"BusinessName": "Penang Flavours"}
establishments.update_one(query, {'$set' :{'BusinessTypeID':1}})
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Confirm that the new restaurant was updated
query = {"BusinessName": "Penange Flavours"}
results = establishments.find(query)

for result in results:
    pprint(result)

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query = {'LocalAuthorityName': 'Dover'}

print("Number of documents in Dover:", establishments.count_documents(query))
# Out:
# Number of documents in Dover: 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
query = {'LocalAuthorityName': 'Dover'}
establishments.delete_many(query)
# Out:
# DeleteResult({'n': 994, 'ok': 1.0}, acknowledged=True)

# %%
# Check if any remaining documents include Dover
query = {'LocalAuthorityName': 'Dover'}
print("Number of documents in Dover:", establishments.count_documents(query))
# Out:
# Number of documents in Dover: 0

# %%
# Check that other documents remain with 'find_one'
establishments.find_one({})
# Out:
# {'_id': ObjectId('66d6400859618f317ba9398e'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.195625', 'latitude': '51.083812'},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({}, [{'$set': {
    "geocode.longitude": {'$toDouble': '$geocode.longitude'},
    "geocode.latitude": {'$toDouble': '$geocode.latitude'}
    }
    }])
# Out:
# UpdateResult({'n': 38786, 'nModified': 38786, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Verify longitude and latitude are doubles
establishments.find_one({})

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])
# Out:
# UpdateResult({'n': 4091, 'nModified': 4091, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, [{'$set': {
    "RatingValue": {'$toInt': "$RatingValue"},
    }
    }])
# Out:
# UpdateResult({'n': 38786, 'nModified': 34695, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Check that the coordinates and rating value are now numbers
establishments.find_one({})
# Out:
# {'_id': ObjectId('66d6400859618f317ba9398e'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': 5,
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 1.195625, 'latitude': 51.083812},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}
